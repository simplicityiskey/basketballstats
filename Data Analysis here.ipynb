# %%
import pandas as pd
import numpy as np
import seaborn

# %%
df = pd.read_csv('NBA_Player_Stats.csv')

# %%
df.head()
# Out:
#    Rk               Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0   1   Mahmoud Abdul-Rauf  PG   28  SAC  31   0  17.1  3.3   8.8  ...  0.2
# 1   2    Tariq Abdul-Wahad  SG   23  SAC  59  16  16.3  2.4   6.1  ...  0.7
# 2   3  Shareef Abdur-Rahim  SF   21  VAN  82  82  36.0  8.0  16.4  ...  2.8
# 3   4       Cory Alexander  PG   24  TOT  60  22  21.6  2.9   6.7  ...  0.3
# 4   4       Cory Alexander  PG   24  SAS  37   3  13.5  1.6   3.9  ...  0.2
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS       Year
# 0  1.0  1.2  1.9  0.5  0.0  0.6  1.0   7.3  1997-1998
# 1  1.2  2.0  0.9  0.6  0.2  1.1  1.4   6.4  1997-1998
# 2  4.3  7.1  2.6  1.1  0.9  3.1  2.5  22.3  1997-1998
# 3  2.2  2.4  3.5  1.2  0.2  1.9  1.6   8.1  1997-1998
# 4  1.1  1.3  1.9  0.7  0.1  1.3  1.4   4.5  1997-1998
#
# [5 rows x 31 columns]

# %%
#The above shows that there are 14573 records or rows withint the dataset.
df.shape
# Out:
# (14573, 31)

# %%
#This shows the amount of null values in the dataset. 
nan_count = df.isnull().sum()
print(nan_count)
# Out:
# Rk           0
# Player       0
# Pos          0
# Age          0
# Tm           0
# G            0
# GS           0
# MP           0
# FG           0
# FGA          0
# FG%         88
# 3P           0
# 3PA          0
# 3P%       2198
# 2P           0
# 2PA          0
# 2P%        154
# eFG%        88
# FT           0
# FTA          0
# FT%        749
# ORB          0
# DRB          0
# TRB          0
# AST          0
# STL          0
# BLK          0
# TOV          0
# PF           0
# PTS          0
# Year         0
# dtype: int64

# %% [markdown]
# We can see that the percentages of the FT, FG, eFG and the 3P are all miissing values and although I could remove the values from the data. I would be able to use the data in the other coloumns to ensure that the data is filled in accurately.
#
# Although there is some difference to the required data in terms of calculated percetages (off by 1%-2% each time) I think that keeping the data will be more valuable to try and see 'general' trends.

# %%
df_view = df.iloc[:, 8:21]
df_view.head()
# Out:
#     FG   FGA    FG%   3P  3PA    3P%   2P   2PA    2P%   eFG%   FT  FTA    FT%
# 0  3.3   8.8  0.377  0.2  1.0  0.161  3.2   7.8  0.405  0.386  0.5  0.5  1.000
# 1  2.4   6.1  0.403  0.1  0.3  0.211  2.4   5.7  0.414  0.409  1.4  2.1  0.672
# 2  8.0  16.4  0.485  0.3  0.6  0.412  7.7  15.8  0.488  0.493  6.1  7.8  0.784
# 3  2.9   6.7  0.428  1.1  2.9  0.375  1.8   3.7  0.469  0.510  1.3  1.7  0.784
# 4  1.6   3.9  0.414  0.5  1.7  0.313  1.1   2.2  0.494  0.483  0.7  1.0  0.676

# %%
holder1 = df_view.isnull()
rows_with_missing_values = df_view[holder1.any(axis=1)]

# %%
rows_with_missing_values.head(25)
# Out:
#       FG  FGA    FG%   3P  3PA    3P%   2P  2PA    2P%   eFG%   FT  FTA    FT%
# 27   1.6  2.9  0.537  0.0  0.0    NaN  1.6  2.9  0.537  0.537  1.4  2.1  0.633
# 39   1.0  2.5  0.400  0.0  0.0    NaN  1.0  2.5  0.400  0.400  1.0  1.0  1.000
# 41   0.0  0.8  0.000  0.0  0.0    NaN  0.0  0.8  0.000  0.000  0.0  0.0    NaN
# 53   3.8  8.0  0.471  0.0  0.0    NaN  3.8  8.0  0.471  0.471  2.0  2.7  0.766
# 67   0.0  0.0    NaN  0.0  0.0    NaN  0.0  0.0    NaN    NaN  0.0  0.0    NaN
# 70   2.3  4.9  0.465  0.0  0.0    NaN  2.3  4.9  0.465  0.465  1.2  1.5  0.776
# 74   1.0  2.4  0.416  0.0  0.0    NaN  1.0  2.4  0.416  0.416  0.4  0.7  0.577
# 78   2.0  2.0  1.000  0.0  0.0    NaN  2.0  2.0  1.000  1.000  2.0  2.0  1.000
# 84   1.6  3.6  0.449  0.0  0.0    NaN  1.6  3.6  0.449  0.449  0.8  1.3  0.597
# 88   1.6  3.4  0.452  0.0  0.0    NaN  1.6  3.4  0.452  0.452  1.8  2.4  0.727
# 96   3.4  7.2  0.477  0.0  0.0    NaN  3.4  7.2  0.477  0.477  0.9  1.3  0.700
# ...

# %%
df['FG%'].fillna(((df['FG']/df['FGA'])/100), inplace =True)
df.head(70)
# Out:
#     Rk               Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0    1   Mahmoud Abdul-Rauf  PG   28  SAC  31   0  17.1  3.3   8.8  ...  0.2
# 1    2    Tariq Abdul-Wahad  SG   23  SAC  59  16  16.3  2.4   6.1  ...  0.7
# 2    3  Shareef Abdur-Rahim  SF   21  VAN  82  82  36.0  8.0  16.4  ...  2.8
# 3    4       Cory Alexander  PG   24  TOT  60  22  21.6  2.9   6.7  ...  0.3
# 4    4       Cory Alexander  PG   24  SAS  37   3  13.5  1.6   3.9  ...  0.2
# ..  ..                  ...  ..  ...  ...  ..  ..   ...  ...   ...  ...  ...
# 65  55         Jason Caffey  PF   24  GSW  29   6  24.6  4.3   9.2  ...  2.9
# 66  56         Michael Cage   C   36  NJN  79  17  15.2  0.5   1.1  ...  1.5
# 67  57      Adrian Caldwell  PF   31  DAL   1   0   3.0  0.0   0.0  ...  0.0
# 68  58         Marcus Camby   C   23  TOR  63  58  31.8  4.9  11.9  ...  3.2
# 69  59       Elden Campbell  PF   29  LAL  81  28  22.0  3.6   7.7  ...  1.8
#
# ...

# %%
nan_counts=df.isnull().sum()
nan_counts
# Out:
# Rk           0
# Player       0
# Pos          0
# Age          0
# Tm           0
# G            0
# GS           0
# MP           0
# FG           0
# FGA          0
# FG%         88
# 3P           0
# 3PA          0
# 3P%       2198
# 2P           0
# 2PA          0
# 2P%        154
# eFG%        88
# FT           0
# FTA          0
# FT%        749
# ORB          0
# DRB          0
# TRB          0
# AST          0
# STL          0
# BLK          0
# TOV          0
# PF           0
# PTS          0
# Year         0
# dtype: int64
